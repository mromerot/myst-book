# %% [markdown]
# ---
# title: Trabajando con MyST Markdown
# subtitle: En JupyterLab
# license: CC-BY-4.0
# github: https://github.com/executablebooks/mystjs
# subject: Tutoial
# venue: MyST Markdown
# biblio:
#   volume: '1'
#   issue: '42'
# authos:
#   - name: Rowan Cockett
#     email: rowan@curvenote.com
#     coresponding: true
#     ocid: 0000-0002-7859-8394
#     affiliations:
#       - Curvenote
#       - ExecutableBooks
# date: 2023/07/05
# ---

# %% [markdown]
# This tutorial on using MyST Markdown in JupyterLab from https://github.com/jupyter-book/jupyterlab-myst-quickstart.git

# %% [markdown]
# MyST (<https://mystmd.og>) es un ecosistema de herramientas de código abierto impulsadas po la comunidad, diseñadas para la comunicación científica, incluyendo un poderoso marco de autoía que admite blogs, libros en línea, artículos científicos, infomes y artículos de revistas!
#
# 🎉 MyST ahoa funciona en JupyterLab 4.0, ver [#142](https://github.com/executablebooks/jupyterlab-myst/pull/142)! 🎉
#
# ## Bienvenido al uso de MyST en Jupyter
#
# :::{impotant} Instalación de MyST Markdown
# Estos notebooks deben renderizarse con `jupyterlab_myst` ([extensión de JupyterLab](https://github.com/executablebooks/jupyterlab-myst)) o `myst` ([herramientas de línea de comandos](https://mystmd.og/guide)).
#
# ``` bash
# # Para trabajar en JupyterLab
# pip install jupyterlab_myst
# # Para trabajar en la línea de comandos
# npm install -g mystmd
# ```
#
# :::
#
# :::{tip} Verificando la `jupyterlab_myst` instalación :class: dropdown Para verificar que la extensión esté registrada con Jupyter, usa:
#
# ``` text
# jupyter labextension list
# ```
#
# Deberías ver el siguiente texto en la salida:
#
# ``` text
# jupyterlab-myst v2.x.x enabled OK
# ```
#
# En Jupyter 4.0 también puedes ver el plugin MyST en el Administrado de extensiones de Jupyter dentro de JupyterLab.
#
# :::{figure} attachment:5d201865-319b-49cf-affa-07789d045463.png :width: 50% En el Administrado de extensiones de Jupyter verás que la extensión MyST está instalada y habilitada. :::

# %% [markdown]
# ## Tutoriales de inicio rápido
#
# 🛠 A lo largo de estos tutoiales, cuando se supone que debes hacer algo verás un 🛠
#
# :::{card} 🧑🏼‍🏫 Fundamentos de MyST Markdown
# :link: ./02-myst-markdown-basics.ipynb
# Incluye figuras y ecuaciones en tus documentos, con referencias cruzadas fáciles de contenido en todo tu sitio web, artículo o documento.
# :::
#
# :::{card} 🪐 Ejecución en línea
# :link: ./03-inline-interactivity.ipynb
# Puedes usar el `{eval}` para evaluar variables directamente dentro de tus celdas markdown, incluyendo widgets, gráficos sparkline y otras variables.
# :::
#
# :::{card} 🏷 Agregando Frontmatter
# :link: ./04-myst-frontmatter.ipynb
# Puedes agregar frontmatter como macros matemáticas, abreviaturas e infomación sobre título, autoes, licencias y afiliaciones.
# :::
